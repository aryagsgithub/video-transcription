# %% [markdown]
# # Project
#
# In this Project, you will bring together many of the tools and techniques that you have learned throughout this course into a final project. You can choose from many different paths to get to the solution.
#
# ### Business scenario
#
# You work for a training organization that recently developed an introductory course about machine learning (ML). The course includes more than 40 videos that cover a broad range of ML topics. You have been asked to create an application that will students can use to quickly locate and view video content by searching for topics and key phrases.
#
# You have downloaded all of the videos to an Amazon Simple Storage Service (Amazon S3) bucket. Your assignment is to produce a dashboard that meets your supervisor’s requirements.

# %% [markdown]
# ## Project steps
#
# To complete this project, you will follow these steps:
#
# 1. [Viewing the video files](#1.-Viewing-the-video-files)
# 2. [Transcribing the videos](#2.-Transcribing-the-videos)
# 3. [Normalizing the text](#3.-Normalizing-the-text)
# 4. [Extracting key phrases and topics](#4.-Extracting-key-phrases-and-topics)
# 5. [Creating the dashboard](#5.-Creating-the-dashboard)

# %% [markdown]
# ## Useful information
#
# The following cell contains some information that might be useful as you complete this project.

# %%
bucket = "c56161a939430l3396553t1w744137092661-labbucket-rn642jaq01e9"
job_data_access_role = 'arn:aws:iam::744137092661:role/service-role/c56161a939430l3396553t1w7-ComprehendDataAccessRole-1P24MSS91ADHP'

# %% [markdown]
# ## 1. Viewing the video files
# ([Go to top](#Capstone-8:-Bringing-It-All-Together))

# %% [markdown]
# The source video files are located in the following shared Amazon Simple Storage Service (Amazon S3) bucket.

# %%
# !aws s3 ls s3://aws-tc-largeobjects/CUR-TF-200-ACMNLP-1/video/
# Out:
# 875.66s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 2021-04-26 20:17:33  410925369 Mod01_Course Overview.mp4
# 2021-04-26 20:10:02   39576695 Mod02_Intro.mp4
# 2021-04-26 20:31:23  302994828 Mod02_Sect01.mp4
# 2021-04-26 20:17:33  416563881 Mod02_Sect02.mp4
# 2021-04-26 20:17:33  318685583 Mod02_Sect03.mp4
# 2021-04-26 20:17:33  255877251 Mod02_Sect04.mp4
# 2021-04-26 20:23:51   99988046 Mod02_Sect05.mp4
# 2021-04-26 20:24:54   50700224 Mod02_WrapUp.mp4
# 2021-04-26 20:26:27   60627667 Mod03_Intro.mp4
# 2021-04-26 20:26:28  272229844 Mod03_Sect01.mp4
# 2021-04-26 20:27:06  309127124 Mod03_Sect02_part1.mp4
# 2021-04-26 20:27:06  195635527 Mod03_Sect02_part2.mp4
# 2021-04-26 20:28:03  123924818 Mod03_Sect02_part3.mp4
# 2021-04-26 20:31:28  171681915 Mod03_Sect03_part1.mp4
# 2021-04-26 20:32:07  285200083 Mod03_Sect03_part2.mp4
# 2021-04-26 20:33:17  105470345 Mod03_Sect03_part3.mp4
# 2021-04-26 20:35:10  157185651 Mod03_Sect04_part1.mp4
# 2021-04-26 20:36:27  187435635 Mod03_Sect04_part2.mp4
# 2021-04-26 20:36:40  280720369 Mod03_Sect04_part3.mp4
# 2021-04-26 20:40:01  443479313 Mod03_Sect05.mp4
# 2021-04-26 20:40:08  234182186 Mod03_Sect06.mp4
# 2021-04-26 20:40:33  207718047 Mod03_Sect07_part1.mp4
# 2021-04-26 20:42:07  125592110 Mod03_Sect07_part2.mp4
# 2021-04-26 20:45:10  508500301 Mod03_Sect07_part3.mp4
# 2021-04-26 20:46:16  320126756 Mod03_Sect08.mp4
# 2021-04-26 20:46:43   41839508 Mod03_WrapUp.mp4
# 2021-04-26 20:46:55   34148489 Mod04_Intro.mp4
# 2021-04-26 20:48:24   84959465 Mod04_Sect01.mp4
# 2021-04-26 20:48:25  345182970 Mod04_Sect02_part1.mp4
# 2021-04-26 20:51:34  218661651 Mod04_Sect02_part2.mp4
# 2021-04-26 20:53:32  430140637 Mod04_Sect02_part3.mp4
# 2021-04-26 20:56:03   22036605 Mod04_WrapUp.mp4
# 2021-04-26 20:57:18   49187118 Mod05_Intro.mp4
# 2021-04-26 20:58:19  245798071 Mod05_Sect01_ver2.mp4
# 2021-04-26 20:58:50  233314835 Mod05_Sect02_part1_ver2.mp4
# 2021-04-26 20:59:14  348545306 Mod05_Sect02_part2.mp4
# 2021-04-26 20:59:17  239142711 Mod05_Sect03_part1.mp4
# 2021-04-26 21:06:04  267533559 Mod05_Sect03_part2.mp4
# 2021-04-26 21:06:06  212502220 Mod05_Sect03_part3.mp4
# 2021-04-26 21:06:48  206317022 Mod05_Sect03_part4_ver2.mp4
# 2021-04-26 21:06:48   60361230 Mod05_WrapUp_ver2.mp4
# 2021-04-26 21:09:14   35397860 Mod06_Intro.mp4
# 2021-04-26 21:09:24  845633599 Mod06_Sect01.mp4
# 2021-04-26 21:10:47  326126684 Mod06_Sect02.mp4
# 2021-04-26 21:12:26   19790740 Mod06_WrapUp.mp4
# 2021-04-26 21:12:56  131249036 Mod07_Sect01.mp4

# %% [markdown]
# ## 2. Transcribing the videos
#  ([Go to top](#Capstone-8:-Bringing-It-All-Together))
#
# Use this section to implement your solution to transcribe the videos.

# %%
import boto3

# Initialize S3 client
s3_client = boto3.client('s3')

# Your S3 bucket name
bucket = "arya-geetha-nlp"

# List all video files
response = s3_client.list_objects_v2(Bucket=bucket)

# Extract filenames of all videos
if 'Contents' in response:
    video_files = [file['Key'] for file in response['Contents'] if file['Key'].endswith('.mp4')]
    print(f"Found {len(video_files)} videos:", video_files)
else:
    print("No video files found in the S3 bucket.")
# Out:
# Found 46 videos: ['Mod01_Course Overview.mp4', 'Mod02_Intro.mp4', 'Mod02_Sect01.mp4', 'Mod02_Sect02.mp4', 'Mod02_Sect03.mp4', 'Mod02_Sect04.mp4', 'Mod02_Sect05.mp4', 'Mod02_WrapUp.mp4', 'Mod03_Intro.mp4', 'Mod03_Sect01.mp4', 'Mod03_Sect02_part1.mp4', 'Mod03_Sect02_part2.mp4', 'Mod03_Sect02_part3.mp4', 'Mod03_Sect03_part1.mp4', 'Mod03_Sect03_part2.mp4', 'Mod03_Sect03_part3.mp4', 'Mod03_Sect04_part1.mp4', 'Mod03_Sect04_part2.mp4', 'Mod03_Sect04_part3.mp4', 'Mod03_Sect05.mp4', 'Mod03_Sect06.mp4', 'Mod03_Sect07_part1.mp4', 'Mod03_Sect07_part2.mp4', 'Mod03_Sect07_part3.mp4', 'Mod03_Sect08.mp4', 'Mod03_WrapUp.mp4', 'Mod04_Intro.mp4', 'Mod04_Sect01.mp4', 'Mod04_Sect02_part1.mp4', 'Mod04_Sect02_part2.mp4', 'Mod04_Sect02_part3.mp4', 'Mod04_WrapUp.mp4', 'Mod05_Intro.mp4', 'Mod05_Sect01_ver2.mp4', 'Mod05_Sect02_part1_ver2.mp4', 'Mod05_Sect02_part2.mp4', 'Mod05_Sect03_part1.mp4', 'Mod05_Sect03_part2.mp4', 'Mod05_Sect03_part3.mp4', 'Mod05_Sect03_part4_ver2.mp4', 'Mod05_WrapUp_ver2.mp4', 'Mod06_Intro.mp4', 'Mod06_Sect01.mp4', 'Mod06_Sect02.mp4', 'Mod06_WrapUp.mp4', 'Mod07_Sect01.mp4']

# %%
# !conda install -c conda-forge ffmpeg -y
# Out:
# 884.37s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Retrieving noticesdone
# Channels:
#  - conda-forge
#  - nvidia
#  - pytorch
# Platform: linux-64
# doneecting package metadata (repodata.json): -
# doneing environment: \
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aws-c-auth-0.8.0           |      hb921021_15         105 KB  conda-forge
#     aws-c-s3-0.7.7             |       hf454442_0         111 KB  conda-forge
#     aws-c-sdkutils-0.2.1       |       h4e1184b_4          55 KB  conda-forge
#     aws-crt-cpp-0.29.7         |       hd92328a_7         346 KB  conda-forge
#     aws-sdk-cpp-1.11.458       |       hc430e4a_4         2.9 MB  conda-forge
#     ffmpeg-7.1.0               | gpl_h4c12d27_707         9.9 MB  conda-forge
#     libarrow-18.1.0            |   h44a453e_6_cpu         8.4 MB  conda-forge
#     libarrow-acero-18.1.0      |   hcb10f89_6_cpu         597 KB  conda-forge
#     libarrow-dataset-18.1.0    |   hcb10f89_6_cpu         573 KB  conda-forge
#     libarrow-substrait-18.1.0  |   h3ee7192_6_cpu         508 KB  conda-forge
#     libass-0.17.3              |       h1dc1e6a_0         130 KB  conda-forge
#     libgoogle-cloud-2.32.0     |       h804f50b_0         1.2 MB  conda-forge
#     libgoogle-cloud-storage-2.32.0|       h0121fbd_0         764 KB  conda-forge
#     libgrpc-1.67.1             |       hc2c308b_0         7.0 MB  conda-forge
#     libopentelemetry-cpp-1.18.0|       h5f02ccb_0         782 KB  conda-forge
#     libopentelemetry-cpp-headers-1.18.0|       ha770c72_0         311 KB  conda-forge
#     libopenvino-2024.5.0       |       hac27bb2_0         5.3 MB  conda-forge
#     libopenvino-auto-batch-plugin-2024.5.0|       h4d9b6c2_0         108 KB  conda-forge
#     libopenvino-auto-plugin-2024.5.0|       h4d9b6c2_0         232 KB  conda-forge
#     libopenvino-hetero-plugin-2024.5.0|       h3f63f65_0         192 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2024.5.0|       hac27bb2_0        11.7 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2024.5.0|       hac27bb2_0         9.1 MB  conda-forge
#     libopenvino-intel-npu-plugin-2024.5.0|       hac27bb2_0         946 KB  conda-forge
#     libopenvino-ir-frontend-2024.5.0|       h3f63f65_0         203 KB  conda-forge
#     libopenvino-onnx-frontend-2024.5.0|       h5c8f2c3_0         1.5 MB  conda-forge
#     libopenvino-paddle-frontend-2024.5.0|       h5c8f2c3_0         643 KB  conda-forge
#     libopenvino-pytorch-frontend-2024.5.0|       h5888daf_0         1.1 MB  conda-forge
#     libopenvino-tensorflow-frontend-2024.5.0|       h6481b9d_0         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2024.5.0|       h5888daf_0         474 KB  conda-forge
#     libparquet-18.1.0          |   h081d1f1_6_cpu         1.1 MB  conda-forge
#     libprotobuf-5.28.2         |       h5b01275_0         2.8 MB  conda-forge
#     librsvg-2.58.4             |       hc0ffecb_0         6.1 MB  conda-forge
#     libutf8proc-2.9.0          |       hb9d3cd8_1          80 KB  conda-forge
#     libva-2.22.0               |       h4f16b4b_2         212 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     ocl-icd-2.3.2              |       hb9d3cd8_2          93 KB  conda-forge
#     opencl-headers-2024.10.24  |       h5888daf_0          53 KB  conda-forge
#     openh264-2.5.0             |       hf92e6e3_0         710 KB  conda-forge
#     orc-2.0.3                  |       h97ab989_1         1.1 MB  conda-forge
#     pugixml-1.14               |       h59595ed_0         112 KB  conda-forge
#     pyarrow-18.1.0             |  py310hff52083_0          25 KB  conda-forge
#     pyarrow-core-18.1.0        |py310hac404ae_0_cpu         4.3 MB  conda-forge
#     wayland-protocols-1.41     |       hd8ed1ab_0         127 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        88.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.0-gpl_h4c12d27_707
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   libass             conda-forge/linux-64::libass-0.17.3-h1dc1e6a_0
#   libopenvino        conda-forge/linux-64::libopenvino-2024.5.0-hac27bb2_0
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2024.5.0-h4d9b6c2_0
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2024.5.0-h4d9b6c2_0
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2024.5.0-h3f63f65_0
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2024.5.0-hac27bb2_0
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2024.5.0-hac27bb2_0
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2024.5.0-hac27bb2_0
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2024.5.0-h3f63f65_0
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2024.5.0-h5c8f2c3_0
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2024.5.0-h5c8f2c3_0
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2024.5.0-h5888daf_0
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2024.5.0-h6481b9d_0
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2024.5.0-h5888daf_0
#   librsvg            conda-forge/linux-64::librsvg-2.58.4-hc0ffecb_0
#   libva              conda-forge/linux-64::libva-2.22.0-h4f16b4b_2
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.2-hb9d3cd8_2
#   opencl-headers     conda-forge/linux-64::opencl-headers-2024.10.24-h5888daf_0
#   openh264           conda-forge/linux-64::openh264-2.5.0-hf92e6e3_0
#   pugixml            conda-forge/linux-64::pugixml-1.14-h59595ed_0
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.41-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#
# The following packages will be DOWNGRADED:
#
#   aws-c-auth                               0.8.1-h205f482_0 --> 0.8.0-hb921021_15
#   aws-c-s3                                 0.7.9-he1b24dc_1 --> 0.7.7-hf454442_0
#   aws-c-sdkutils                           0.2.2-h4e1184b_0 --> 0.2.1-h4e1184b_4
#   aws-crt-cpp                             0.29.9-he0e7f3f_2 --> 0.29.7-hd92328a_7
#   aws-sdk-cpp                           1.11.489-h4d475cb_0 --> 1.11.458-hc430e4a_4
#   libarrow                            19.0.0-h00a82cf_8_cpu --> 18.1.0-h44a453e_6_cpu
#   libarrow-acero                      19.0.0-hcb10f89_8_cpu --> 18.1.0-hcb10f89_6_cpu
#   libarrow-dataset                    19.0.0-hcb10f89_8_cpu --> 18.1.0-hcb10f89_6_cpu
#   libarrow-substrait                  19.0.0-h08228c5_8_cpu --> 18.1.0-h3ee7192_6_cpu
#   libgoogle-cloud                         2.34.0-h2b5623c_0 --> 2.32.0-h804f50b_0
#   libgoogle-cloud-s~                      2.34.0-h0121fbd_0 --> 2.32.0-h0121fbd_0
#   libgrpc                                 1.67.1-h25350d4_1 --> 1.67.1-hc2c308b_0
#   libopentelemetry-~                      1.18.0-hfcad708_1 --> 1.18.0-h5f02ccb_0
#   libopentelemetry-~                      1.18.0-ha770c72_1 --> 1.18.0-ha770c72_0
#   libparquet                          19.0.0-h081d1f1_8_cpu --> 18.1.0-h081d1f1_6_cpu
#   libprotobuf                             5.28.3-h6128344_1 --> 5.28.2-h5b01275_0
#   libutf8proc                             2.10.0-h4c51ac1_0 --> 2.9.0-hb9d3cd8_1
#   orc                                      2.0.3-h12ee42a_2 --> 2.0.3-h97ab989_1
#   pyarrow                            19.0.0-py310hff52083_0 --> 18.1.0-py310hff52083_0
#   pyarrow-core                   19.0.0-py310hac404ae_0_cpu --> 18.1.0-py310hac404ae_0_cpu
#
#
#
# Downloading and Extracting Packages:
# libopenvino-intel-cp | 11.7 MB   |                                       |   0%
# ffmpeg-7.1.0         | 9.9 MB    |                                       |   0%
#
# libopenvino-intel-gp | 9.1 MB    |                                       |   0%
#
#
# libarrow-18.1.0      | 8.4 MB    |                                       |   0%
#
#
#
# libgrpc-1.67.1       | 7.0 MB    |                                       |   0%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    |                                       |   0%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    |                                       |   0%
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 4.3 MB    |                                       |   0%
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-2.32 | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libparquet-18.1.0    | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.3            | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 946 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopentelemetry-cpp | 782 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 764 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.5.0       | 710 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# libarrow-18.1.0      | 8.4 MB    |                                       |   0%
# ffmpeg-7.1.0         | 9.9 MB    |                                       |   0%
#
#
#
# libopenvino-intel-cp | 11.7 MB   |                                       |   0%
#
# libopenvino-intel-cp | 11.7 MB   | #######                               |  19%
#
#
#
# libgrpc-1.67.1       | 7.0 MB    | ########8                             |  24%
#
#
# libarrow-18.1.0      | 8.4 MB    | ########9                             |  24%
# ffmpeg-7.1.0         | 9.9 MB    | ########9                             |  24%
#
# libopenvino-intel-gp | 9.1 MB    | #####3                                |  14%
#
#
#
# libopenvino-intel-cp | 11.7 MB   | #############8                        |  38%
#
#
# libarrow-18.1.0      | 8.4 MB    | ##################7                   |  51%
# ffmpeg-7.1.0         | 9.9 MB    | #################5                    |  48%
#
# libopenvino-intel-gp | 9.1 MB    | ###############2                      |  41%
#
#
#
# libopenvino-intel-cp | 11.7 MB   | ###########################1          |  73%
#
#
# libarrow-18.1.0      | 8.4 MB    | ##################################4   |  93%
# ffmpeg-7.1.0         | 9.9 MB    | ############################6         |  77%
#
#
#
# libgrpc-1.67.1       | 7.0 MB    | ##################################### | 100%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    |                                       |   0%
#
# libopenvino-intel-gp | 9.1 MB    | ##################################### | 100%
#
# libopenvino-intel-gp | 9.1 MB    | ##################################### | 100%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    | 1                                     |   0%
#
#
# libarrow-18.1.0      | 8.4 MB    | ##################################### | 100%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ##############6                       |  39%
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 4.3 MB    | 1                                     |   0%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    | ###########2                          |  30%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ######################7               |  62%
# ffmpeg-7.1.0         | 9.9 MB    | ##################################### | 100%
# ffmpeg-7.1.0         | 9.9 MB    | ##################################### | 100%
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 4.3 MB    | ###########2                          |  30%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    | ########################1             |  65%
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | 1                                     |   0%
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 4.3 MB    | ##################################    |  92%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ##############################6       |  83%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    | #################################4    |  90%
#
#
#
#
#
#
#
# libopenvino-intel-cp | 11.7 MB   | ##################################### | 100%
#
#
#
#
#
#
# pyarrow-core-18.1.0  | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    | ##################################### | 100%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.9 MB    | 1                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-2.32 | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | ##########################9           |  73%
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.9 MB    | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-2.32 | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-2.32 | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libparquet-18.1.0    | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libparquet-18.1.0    | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.3            | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | 5                                     |   2%
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.3            | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 946 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 764 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopentelemetry-cpp | 782 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.5.0       | 710 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopentelemetry-cpp | 782 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 946 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 764 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.5.0       | 710 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libopenvino-intel-gp | 9.1 MB    | ##################################### | 100%
#
#
#
# libgrpc-1.67.1       | 7.0 MB    | ##################################### | 100%
#
#
# libarrow-18.1.0      | 8.4 MB    | ##################################### | 100%
# ffmpeg-7.1.0         | 9.9 MB    | ##################################### | 100%
#
#
#
#
#
#
# libopenvino-intel-cp | 11.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
# libopenvino-2024.5.0 | 5.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-2.32 | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
# librsvg-2.58.4       | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libparquet-18.1.0    | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libparquet-18.1.0    | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libprotobuf-5.28.2   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.3            | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# orc-2.0.3            | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.11.458 | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopentelemetry-cpp | 782 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopentelemetry-cpp | 782 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 946 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 946 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 764 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgoogle-cloud-stor | 764 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.5.0       | 710 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.5.0       | 710 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# donearing transaction: /
# donefying transaction: \
# \
# -
# done

# %%
# !pip install openai-whisper torch
# Out:
# 1054.51s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: openai-whisper in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (20240930)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: numba in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai-whisper) (0.61.0)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai-whisper) (1.26.4)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai-whisper) (4.67.1)
# Requirement already satisfied: more-itertools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai-whisper) (10.6.0)
# Requirement already satisfied: tiktoken in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai-whisper) (0.9.0)
# Requirement already satisfied: triton>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai-whisper) (3.2.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.4)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from numba->openai-whisper) (0.44.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.1.31)

# %%
# Generate temporary links for each video
presigned_urls = {}
for video in video_files:
    url = s3_client.generate_presigned_url(
        'get_object',
        Params={'Bucket': bucket, 'Key': video},
        ExpiresIn=86400  # Link valid for 1 hour
    )
    presigned_urls[video] = url

print("Generated pre-signed URLs for videos.")
# Out:
# Generated pre-signed URLs for videos.

# %%
import os
import boto3

def download_mp4_files_from_s3(bucket_name, local_directory):
    """
    Downloads all .mp4 files from the specified S3 bucket to a local directory.

    Args:
        bucket_name (str): Name of the S3 bucket.
        local_directory (str): Local directory to save the downloaded files.
    """
    # Initialize the S3 client
    s3_client = boto3.client('s3')

    # Create the local directory if it doesn't exist
    if not os.path.exists(local_directory):
        os.makedirs(local_directory)
        print(f"Created local directory: {local_directory}")

    try:
        # List all objects in the S3 bucket
        bucket_objects = s3_client.list_objects_v2(Bucket=bucket_name)

        # Check if the bucket contains any objects
        if 'Contents' not in bucket_objects:
            print(f"The bucket '{bucket_name}' is empty or does not exist.")
            return

        # Iterate through each object in the bucket
        for obj in bucket_objects['Contents']:
            file_key = obj['Key']

            # Check if the file is a .mp4 file
            if file_key.lower().endswith('.mp4'):
                # Construct the local file path
                file_name = os.path.basename(file_key)
                local_file_path = os.path.join(local_directory, file_name)

                # Download the file
                s3_client.download_file(bucket_name, file_key, local_file_path)
                print(f"Downloaded '{file_key}' to '{local_file_path}'")

    except Exception as e:
        print(f"An error occurred while downloading files: {e}")

# Example usage
if __name__ == "__main__":
    # Specify the S3 bucket name and local directory
    s3_bucket = 'arya-geetha-nlp'
    local_folder = 'videos'

    # Call the function to download .mp4 files
    download_mp4_files_from_s3(s3_bucket, local_folder)
# Out:
# Downloaded 'Mod01_Course Overview.mp4' to 'videos/Mod01_Course Overview.mp4'
# Downloaded 'Mod02_Intro.mp4' to 'videos/Mod02_Intro.mp4'
# Downloaded 'Mod02_Sect01.mp4' to 'videos/Mod02_Sect01.mp4'
# Downloaded 'Mod02_Sect02.mp4' to 'videos/Mod02_Sect02.mp4'
# Downloaded 'Mod02_Sect03.mp4' to 'videos/Mod02_Sect03.mp4'
# Downloaded 'Mod02_Sect04.mp4' to 'videos/Mod02_Sect04.mp4'
# Downloaded 'Mod02_Sect05.mp4' to 'videos/Mod02_Sect05.mp4'
# Downloaded 'Mod02_WrapUp.mp4' to 'videos/Mod02_WrapUp.mp4'
# Downloaded 'Mod03_Intro.mp4' to 'videos/Mod03_Intro.mp4'
# Downloaded 'Mod03_Sect01.mp4' to 'videos/Mod03_Sect01.mp4'
# Downloaded 'Mod03_Sect02_part1.mp4' to 'videos/Mod03_Sect02_part1.mp4'
# Downloaded 'Mod03_Sect02_part2.mp4' to 'videos/Mod03_Sect02_part2.mp4'
# Downloaded 'Mod03_Sect02_part3.mp4' to 'videos/Mod03_Sect02_part3.mp4'
# Downloaded 'Mod03_Sect03_part1.mp4' to 'videos/Mod03_Sect03_part1.mp4'
# Downloaded 'Mod03_Sect03_part2.mp4' to 'videos/Mod03_Sect03_part2.mp4'
# Downloaded 'Mod03_Sect03_part3.mp4' to 'videos/Mod03_Sect03_part3.mp4'
# Downloaded 'Mod03_Sect04_part1.mp4' to 'videos/Mod03_Sect04_part1.mp4'
# Downloaded 'Mod03_Sect04_part2.mp4' to 'videos/Mod03_Sect04_part2.mp4'
# Downloaded 'Mod03_Sect04_part3.mp4' to 'videos/Mod03_Sect04_part3.mp4'
# Downloaded 'Mod03_Sect05.mp4' to 'videos/Mod03_Sect05.mp4'
# Downloaded 'Mod03_Sect06.mp4' to 'videos/Mod03_Sect06.mp4'
# Downloaded 'Mod03_Sect07_part1.mp4' to 'videos/Mod03_Sect07_part1.mp4'
# Downloaded 'Mod03_Sect07_part2.mp4' to 'videos/Mod03_Sect07_part2.mp4'
# Downloaded 'Mod03_Sect07_part3.mp4' to 'videos/Mod03_Sect07_part3.mp4'
# Downloaded 'Mod03_Sect08.mp4' to 'videos/Mod03_Sect08.mp4'
# Downloaded 'Mod03_WrapUp.mp4' to 'videos/Mod03_WrapUp.mp4'
# Downloaded 'Mod04_Intro.mp4' to 'videos/Mod04_Intro.mp4'
# Downloaded 'Mod04_Sect01.mp4' to 'videos/Mod04_Sect01.mp4'
# Downloaded 'Mod04_Sect02_part1.mp4' to 'videos/Mod04_Sect02_part1.mp4'
# Downloaded 'Mod04_Sect02_part2.mp4' to 'videos/Mod04_Sect02_part2.mp4'
# Downloaded 'Mod04_Sect02_part3.mp4' to 'videos/Mod04_Sect02_part3.mp4'
# Downloaded 'Mod04_WrapUp.mp4' to 'videos/Mod04_WrapUp.mp4'
# Downloaded 'Mod05_Intro.mp4' to 'videos/Mod05_Intro.mp4'
# Downloaded 'Mod05_Sect01_ver2.mp4' to 'videos/Mod05_Sect01_ver2.mp4'
# Downloaded 'Mod05_Sect02_part1_ver2.mp4' to 'videos/Mod05_Sect02_part1_ver2.mp4'
# Downloaded 'Mod05_Sect02_part2.mp4' to 'videos/Mod05_Sect02_part2.mp4'
# Downloaded 'Mod05_Sect03_part1.mp4' to 'videos/Mod05_Sect03_part1.mp4'
# Downloaded 'Mod05_Sect03_part2.mp4' to 'videos/Mod05_Sect03_part2.mp4'
# Downloaded 'Mod05_Sect03_part3.mp4' to 'videos/Mod05_Sect03_part3.mp4'
# Downloaded 'Mod05_Sect03_part4_ver2.mp4' to 'videos/Mod05_Sect03_part4_ver2.mp4'
# Downloaded 'Mod05_WrapUp_ver2.mp4' to 'videos/Mod05_WrapUp_ver2.mp4'
# Downloaded 'Mod06_Intro.mp4' to 'videos/Mod06_Intro.mp4'
# Downloaded 'Mod06_Sect01.mp4' to 'videos/Mod06_Sect01.mp4'
# Downloaded 'Mod06_Sect02.mp4' to 'videos/Mod06_Sect02.mp4'
# Downloaded 'Mod06_WrapUp.mp4' to 'videos/Mod06_WrapUp.mp4'
# Downloaded 'Mod07_Sect01.mp4' to 'videos/Mod07_Sect01.mp4'

# %%
s3_uri = os.path.join("videos")
output_uri = os.path.join("transcribed")

# %%
import os
import subprocess
import whisper
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

class VideoTranscriber:
    def __init__(self, model_name="base"):
        """Initializes the VideoTranscriber with a Whisper model."""
        self.model = whisper.load_model(model_name)
        logging.info(f"Loaded Whisper model: {model_name}")

    def extract_audio(self, video_path, audio_path):
        """Extracts audio from a video file using ffmpeg."""
        try:
            command = [
                'ffmpeg', '-i', video_path, '-q:a', '0', '-map', 'a', audio_path, '-y'
            ]
            subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True)
            logging.info(f"Extracted audio from {video_path} to {audio_path}")
            return audio_path
        except subprocess.CalledProcessError as e:
            logging.error(f"Failed to extract audio from {video_path}: {e}")
            return None

    def transcribe_audio(self, audio_path):
        """Transcribes an audio file using Whisper."""
        try:
            result = self.model.transcribe(audio_path)
            logging.info(f"Transcribed audio from {audio_path}")
            return result["text"]
        except Exception as e:
            logging.error(f"Failed to transcribe audio from {audio_path}: {e}")
            return None

    def process_video(self, video_path):
        """Processes a video file by extracting audio and transcribing it."""
        audio_path = video_path.rsplit('.', 1)[0] + ".mp3"
        if self.extract_audio(video_path, audio_path):
            transcript = self.transcribe_audio(audio_path)
            if transcript:
                return transcript
        return None

def main():
    video_dir = "videos"  # Directory containing video files
    transcriber = VideoTranscriber(model_name="base")
    transcripts = {}

    # Process each video file in the directory
    for video_file in os.listdir(video_dir):
        if video_file.endswith(('.mp4', '.mkv', '.avi', '.mov')):  # Add more formats if needed
            video_path = os.path.join(video_dir, video_file)
            logging.info(f"Processing {video_file}...")
            transcript = transcriber.process_video(video_path)
            if transcript:
                transcripts[video_file] = transcript
            else:
                logging.warning(f"Skipped {video_file} due to errors.")

    # Save all transcripts to a text file
    with open("transcriptions.txt", "w") as f:
        for video, text in transcripts.items():
            f.write(f"{video}\n{text}\n\n")

    logging.info("Transcription complete. Saved to transcriptions.txt.")

if __name__ == "__main__":
    main()
# Out:
# 2025-03-15 00:16:42,078 - INFO - Loaded Whisper model: base
# 2025-03-15 00:16:42,079 - INFO - Processing Mod04_Intro.mp4...
# 2025-03-15 00:16:43,061 - INFO - Extracted audio from videos/Mod04_Intro.mp4 to videos/Mod04_Intro.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:16:56,249 - INFO - Transcribed audio from videos/Mod04_Intro.mp3
# 2025-03-15 00:16:56,250 - INFO - Processing Mod03_Intro.mp4...
# 2025-03-15 00:16:58,312 - INFO - Extracted audio from videos/Mod03_Intro.mp4 to videos/Mod03_Intro.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:17:22,755 - INFO - Transcribed audio from videos/Mod03_Intro.mp3
# 2025-03-15 00:17:22,757 - INFO - Processing Mod06_Intro.mp4...
# 2025-03-15 00:17:23,979 - INFO - Extracted audio from videos/Mod06_Intro.mp4 to videos/Mod06_Intro.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:17:36,802 - INFO - Transcribed audio from videos/Mod06_Intro.mp3
# 2025-03-15 00:17:36,804 - INFO - Processing Mod02_Intro.mp4...
# 2025-03-15 00:17:38,345 - INFO - Extracted audio from videos/Mod02_Intro.mp4 to videos/Mod02_Intro.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:17:54,500 - INFO - Transcribed audio from videos/Mod02_Intro.mp3
# 2025-03-15 00:17:54,501 - INFO - Processing Mod03_Sect07_part1.mp4...
# 2025-03-15 00:17:59,441 - INFO - Extracted audio from videos/Mod03_Sect07_part1.mp4 to videos/Mod03_Sect07_part1.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:18:54,701 - INFO - Transcribed audio from videos/Mod03_Sect07_part1.mp3
# 2025-03-15 00:18:54,702 - INFO - Processing Mod03_Sect04_part2.mp4...
# 2025-03-15 00:19:03,317 - INFO - Extracted audio from videos/Mod03_Sect04_part2.mp4 to videos/Mod03_Sect04_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:20:17,045 - INFO - Transcribed audio from videos/Mod03_Sect04_part2.mp3
# 2025-03-15 00:20:17,046 - INFO - Processing Mod06_Sect02.mp4...
# 2025-03-15 00:20:27,935 - INFO - Extracted audio from videos/Mod06_Sect02.mp4 to videos/Mod06_Sect02.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:22:40,683 - INFO - Transcribed audio from videos/Mod06_Sect02.mp3
# 2025-03-15 00:22:40,687 - INFO - Processing Mod03_Sect03_part1.mp4...
# 2025-03-15 00:22:46,703 - INFO - Extracted audio from videos/Mod03_Sect03_part1.mp4 to videos/Mod03_Sect03_part1.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:23:56,772 - INFO - Transcribed audio from videos/Mod03_Sect03_part1.mp3
# 2025-03-15 00:23:56,774 - INFO - Processing Mod04_Sect01.mp4...
# 2025-03-15 00:23:59,730 - INFO - Extracted audio from videos/Mod04_Sect01.mp4 to videos/Mod04_Sect01.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:24:31,349 - INFO - Transcribed audio from videos/Mod04_Sect01.mp3
# 2025-03-15 00:24:31,350 - INFO - Processing Mod02_Sect03.mp4...
# 2025-03-15 00:24:42,346 - INFO - Extracted audio from videos/Mod02_Sect03.mp4 to videos/Mod02_Sect03.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:26:59,901 - INFO - Transcribed audio from videos/Mod02_Sect03.mp3
# 2025-03-15 00:26:59,902 - INFO - Processing Mod03_WrapUp.mp4...
# 2025-03-15 00:27:01,552 - INFO - Extracted audio from videos/Mod03_WrapUp.mp4 to videos/Mod03_WrapUp.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:27:16,960 - INFO - Transcribed audio from videos/Mod03_WrapUp.mp3
# 2025-03-15 00:27:16,961 - INFO - Processing Mod03_Sect08.mp4...
# 2025-03-15 00:27:28,217 - INFO - Extracted audio from videos/Mod03_Sect08.mp4 to videos/Mod03_Sect08.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:29:37,442 - INFO - Transcribed audio from videos/Mod03_Sect08.mp3
# 2025-03-15 00:29:37,443 - INFO - Processing Mod06_WrapUp.mp4...
# 2025-03-15 00:29:38,060 - INFO - Extracted audio from videos/Mod06_WrapUp.mp4 to videos/Mod06_WrapUp.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:29:46,969 - INFO - Transcribed audio from videos/Mod06_WrapUp.mp3
# 2025-03-15 00:29:46,973 - INFO - Processing Mod07_Sect01.mp4...
# 2025-03-15 00:29:51,352 - INFO - Extracted audio from videos/Mod07_Sect01.mp4 to videos/Mod07_Sect01.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:30:42,089 - INFO - Transcribed audio from videos/Mod07_Sect01.mp3
# 2025-03-15 00:30:42,090 - INFO - Processing Mod03_Sect02_part2.mp4...
# 2025-03-15 00:30:48,628 - INFO - Extracted audio from videos/Mod03_Sect02_part2.mp4 to videos/Mod03_Sect02_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:32:07,783 - INFO - Transcribed audio from videos/Mod03_Sect02_part2.mp3
# 2025-03-15 00:32:07,785 - INFO - Processing Mod03_Sect02_part3.mp4...
# 2025-03-15 00:32:11,933 - INFO - Extracted audio from videos/Mod03_Sect02_part3.mp4 to videos/Mod03_Sect02_part3.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:33:04,643 - INFO - Transcribed audio from videos/Mod03_Sect02_part3.mp3
# 2025-03-15 00:33:04,644 - INFO - Processing Mod04_Sect02_part3.mp4...
# 2025-03-15 00:33:19,691 - INFO - Extracted audio from videos/Mod04_Sect02_part3.mp4 to videos/Mod04_Sect02_part3.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:36:06,578 - INFO - Transcribed audio from videos/Mod04_Sect02_part3.mp3
# 2025-03-15 00:36:06,579 - INFO - Processing Mod05_Sect02_part1_ver2.mp4...
# 2025-03-15 00:36:17,706 - INFO - Extracted audio from videos/Mod05_Sect02_part1_ver2.mp4 to videos/Mod05_Sect02_part1_ver2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:38:13,116 - INFO - Transcribed audio from videos/Mod05_Sect02_part1_ver2.mp3
# 2025-03-15 00:38:13,117 - INFO - Processing Mod03_Sect04_part1.mp4...
# 2025-03-15 00:38:18,319 - INFO - Extracted audio from videos/Mod03_Sect04_part1.mp4 to videos/Mod03_Sect04_part1.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:39:18,605 - INFO - Transcribed audio from videos/Mod03_Sect04_part1.mp3
# 2025-03-15 00:39:18,606 - INFO - Processing Mod04_WrapUp.mp4...
# 2025-03-15 00:39:19,534 - INFO - Extracted audio from videos/Mod04_WrapUp.mp4 to videos/Mod04_WrapUp.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:39:29,134 - INFO - Transcribed audio from videos/Mod04_WrapUp.mp3
# 2025-03-15 00:39:29,135 - INFO - Processing Mod05_WrapUp_ver2.mp4...
# 2025-03-15 00:39:30,108 - INFO - Extracted audio from videos/Mod05_WrapUp_ver2.mp4 to videos/Mod05_WrapUp_ver2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:39:42,348 - INFO - Transcribed audio from videos/Mod05_WrapUp_ver2.mp3
# 2025-03-15 00:39:42,349 - INFO - Processing Mod06_Sect01.mp4...
# 2025-03-15 00:39:58,613 - INFO - Extracted audio from videos/Mod06_Sect01.mp4 to videos/Mod06_Sect01.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:43:08,006 - INFO - Transcribed audio from videos/Mod06_Sect01.mp3
# 2025-03-15 00:43:08,007 - INFO - Processing Mod03_Sect07_part2.mp4...
# 2025-03-15 00:43:11,845 - INFO - Extracted audio from videos/Mod03_Sect07_part2.mp4 to videos/Mod03_Sect07_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:44:04,910 - INFO - Transcribed audio from videos/Mod03_Sect07_part2.mp3
# 2025-03-15 00:44:04,914 - INFO - Processing Mod03_Sect07_part3.mp4...
# 2025-03-15 00:44:15,148 - INFO - Extracted audio from videos/Mod03_Sect07_part3.mp4 to videos/Mod03_Sect07_part3.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:46:21,911 - INFO - Transcribed audio from videos/Mod03_Sect07_part3.mp3
# 2025-03-15 00:46:21,913 - INFO - Processing Mod05_Sect01_ver2.mp4...
# 2025-03-15 00:46:31,197 - INFO - Extracted audio from videos/Mod05_Sect01_ver2.mp4 to videos/Mod05_Sect01_ver2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:48:22,056 - INFO - Transcribed audio from videos/Mod05_Sect01_ver2.mp3
# 2025-03-15 00:48:22,058 - INFO - Processing Mod03_Sect05.mp4...
# 2025-03-15 00:48:36,202 - INFO - Extracted audio from videos/Mod03_Sect05.mp4 to videos/Mod03_Sect05.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:51:32,586 - INFO - Transcribed audio from videos/Mod03_Sect05.mp3
# 2025-03-15 00:51:32,587 - INFO - Processing Mod02_Sect05.mp4...
# 2025-03-15 00:51:36,118 - INFO - Extracted audio from videos/Mod02_Sect05.mp4 to videos/Mod02_Sect05.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:52:22,681 - INFO - Transcribed audio from videos/Mod02_Sect05.mp3
# 2025-03-15 00:52:22,683 - INFO - Processing Mod03_Sect06.mp4...
# 2025-03-15 00:52:30,352 - INFO - Extracted audio from videos/Mod03_Sect06.mp4 to videos/Mod03_Sect06.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:54:04,184 - INFO - Transcribed audio from videos/Mod03_Sect06.mp3
# 2025-03-15 00:54:04,186 - INFO - Processing Mod05_Intro.mp4...
# 2025-03-15 00:54:06,079 - INFO - Extracted audio from videos/Mod05_Intro.mp4 to videos/Mod05_Intro.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:54:25,196 - INFO - Transcribed audio from videos/Mod05_Intro.mp3
# 2025-03-15 00:54:25,197 - INFO - Processing Mod03_Sect02_part1.mp4...
# 2025-03-15 00:54:35,449 - INFO - Extracted audio from videos/Mod03_Sect02_part1.mp4 to videos/Mod03_Sect02_part1.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:56:48,120 - INFO - Transcribed audio from videos/Mod03_Sect02_part1.mp3
# 2025-03-15 00:56:48,121 - INFO - Processing Mod03_Sect03_part2.mp4...
# 2025-03-15 00:56:58,077 - INFO - Extracted audio from videos/Mod03_Sect03_part2.mp4 to videos/Mod03_Sect03_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 00:58:54,871 - INFO - Transcribed audio from videos/Mod03_Sect03_part2.mp3
# 2025-03-15 00:58:54,872 - INFO - Processing Mod05_Sect03_part3.mp4...
# 2025-03-15 00:59:02,264 - INFO - Extracted audio from videos/Mod05_Sect03_part3.mp4 to videos/Mod05_Sect03_part3.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:00:23,332 - INFO - Transcribed audio from videos/Mod05_Sect03_part3.mp3
# 2025-03-15 01:00:23,334 - INFO - Processing Mod02_WrapUp.mp4...
# 2025-03-15 01:00:25,048 - INFO - Extracted audio from videos/Mod02_WrapUp.mp4 to videos/Mod02_WrapUp.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:00:43,283 - INFO - Transcribed audio from videos/Mod02_WrapUp.mp3
# 2025-03-15 01:00:43,284 - INFO - Processing Mod05_Sect03_part2.mp4...
# 2025-03-15 01:00:51,958 - INFO - Extracted audio from videos/Mod05_Sect03_part2.mp4 to videos/Mod05_Sect03_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:02:42,048 - INFO - Transcribed audio from videos/Mod05_Sect03_part2.mp3
# 2025-03-15 01:02:42,050 - INFO - Processing Mod05_Sect03_part1.mp4...
# 2025-03-15 01:02:50,124 - INFO - Extracted audio from videos/Mod05_Sect03_part1.mp4 to videos/Mod05_Sect03_part1.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:04:23,121 - INFO - Transcribed audio from videos/Mod05_Sect03_part1.mp3
# 2025-03-15 01:04:23,122 - INFO - Processing Mod02_Sect04.mp4...
# 2025-03-15 01:04:31,775 - INFO - Extracted audio from videos/Mod02_Sect04.mp4 to videos/Mod02_Sect04.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:06:15,652 - INFO - Transcribed audio from videos/Mod02_Sect04.mp3
# 2025-03-15 01:06:15,654 - INFO - Processing Mod04_Sect02_part2.mp4...
# 2025-03-15 01:06:22,812 - INFO - Extracted audio from videos/Mod04_Sect02_part2.mp4 to videos/Mod04_Sect02_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:07:50,400 - INFO - Transcribed audio from videos/Mod04_Sect02_part2.mp3
# 2025-03-15 01:07:50,401 - INFO - Processing Mod02_Sect02.mp4...
# 2025-03-15 01:08:05,640 - INFO - Extracted audio from videos/Mod02_Sect02.mp4 to videos/Mod02_Sect02.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:10:51,724 - INFO - Transcribed audio from videos/Mod02_Sect02.mp3
# 2025-03-15 01:10:51,726 - INFO - Processing Mod05_Sect03_part4_ver2.mp4...
# 2025-03-15 01:10:59,960 - INFO - Extracted audio from videos/Mod05_Sect03_part4_ver2.mp4 to videos/Mod05_Sect03_part4_ver2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:12:32,132 - INFO - Transcribed audio from videos/Mod05_Sect03_part4_ver2.mp3
# 2025-03-15 01:12:32,133 - INFO - Processing Mod05_Sect02_part2.mp4...
# 2025-03-15 01:12:44,311 - INFO - Extracted audio from videos/Mod05_Sect02_part2.mp4 to videos/Mod05_Sect02_part2.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:14:59,042 - INFO - Transcribed audio from videos/Mod05_Sect02_part2.mp3
# 2025-03-15 01:14:59,043 - INFO - Processing Mod03_Sect04_part3.mp4...
# 2025-03-15 01:15:10,172 - INFO - Extracted audio from videos/Mod03_Sect04_part3.mp4 to videos/Mod03_Sect04_part3.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:17:04,091 - INFO - Transcribed audio from videos/Mod03_Sect04_part3.mp3
# 2025-03-15 01:17:04,092 - INFO - Processing Mod01_Course Overview.mp4...
# 2025-03-15 01:17:18,814 - INFO - Extracted audio from videos/Mod01_Course Overview.mp4 to videos/Mod01_Course Overview.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:20:06,886 - INFO - Transcribed audio from videos/Mod01_Course Overview.mp3
# 2025-03-15 01:20:06,888 - INFO - Processing Mod03_Sect01.mp4...
# 2025-03-15 01:20:16,289 - INFO - Extracted audio from videos/Mod03_Sect01.mp4 to videos/Mod03_Sect01.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:22:07,381 - INFO - Transcribed audio from videos/Mod03_Sect01.mp3
# 2025-03-15 01:22:07,382 - INFO - Processing Mod04_Sect02_part1.mp4...
# 2025-03-15 01:22:18,947 - INFO - Extracted audio from videos/Mod04_Sect02_part1.mp4 to videos/Mod04_Sect02_part1.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:24:40,416 - INFO - Transcribed audio from videos/Mod04_Sect02_part1.mp3
# 2025-03-15 01:24:40,417 - INFO - Processing Mod03_Sect03_part3.mp4...
# 2025-03-15 01:24:44,251 - INFO - Extracted audio from videos/Mod03_Sect03_part3.mp4 to videos/Mod03_Sect03_part3.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:25:27,367 - INFO - Transcribed audio from videos/Mod03_Sect03_part3.mp3
# 2025-03-15 01:25:27,368 - INFO - Processing Mod02_Sect01.mp4...
# 2025-03-15 01:25:37,758 - INFO - Extracted audio from videos/Mod02_Sect01.mp4 to videos/Mod02_Sect01.mp3
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 2025-03-15 01:27:41,836 - INFO - Transcribed audio from videos/Mod02_Sect01.mp3
# 2025-03-15 01:27:41,838 - INFO - Transcription complete. Saved to transcriptions.txt.

# %%
import csv

# Path to the input text file and output CSV file
input_file = "transcriptions.txt"
output_file = "transcriptions.csv"

# Open the input text file and output CSV file
with open(input_file, "r", encoding="utf-8") as txt_file, open(output_file, mode="w", newline="", encoding="utf-8") as csv_file:
    writer = csv.writer(csv_file)
    
    # Write the header row
    writer.writerow(["video", "transcription"])
    
    # Read the text file line by line
    video_name = None
    transcription = []
    
    for line in txt_file:
        line = line.strip()  # Remove leading/trailing whitespace
        
        # Check if the line is a video name
        if line.endswith((".mp4", ".mkv", ".avi", ".mov")):
            # If we have a previous video, write it to the CSV
            if video_name and transcription:
                writer.writerow([video_name, " ".join(transcription)])
                transcription = []  # Reset transcription for the next video
            
            # Set the current video name
            video_name = line
        
        # Otherwise, add the line to the transcription
        else:
            transcription.append(line)
    
    # Write the last video and transcription to the CSV
    if video_name and transcription:
        writer.writerow([video_name, " ".join(transcription)])

print(f"✅ Converted {input_file} to {output_file}")
# Out:
# ✅ Converted transcriptions.txt to transcriptions.csv

# %% [markdown]
# ## 3. Normalizing the text
# ([Go to top](#Capstone-8:-Bringing-It-All-Together))
#
# Use this section to perform any text normalization steps that are necessary for your solution.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk


# Download NLTK data (run once)
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download('punkt_tab')

nltk.download("averaged_perceptron_tagger")  # For POS tagging

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Normalization function
def normalize_text(text):
    """
    Normalizes text by:
    1. Converting to lowercase
    2. Removing punctuation
    3. Tokenizing
    4. Removing stopwords
    5. Lemmatizing words
    6. Removing extra whitespace
    """
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove stopwords and lemmatize
    stop_words = set(stopwords.words("english"))
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    
    # Join tokens back into a string
    text = " ".join(tokens)
    
    # Remove extra whitespace
    text = " ".join(text.split())
    
    return text

# Path to the input CSV file and output CSV file
input_csv = "transcriptions.csv"
output_csv = "normalized_transcriptions.csv"

# Read the CSV file
df = pd.read_csv(input_csv)

# Normalize the 'transcription' column
df["transcription"] = df["transcription"].apply(normalize_text)

# Save the normalized data to a new CSV file
df.to_csv(output_csv, index=False)

print(f'Normalized input!')
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Normalized input!

# %% [markdown]
# ## 4. Extracting key phrases and topics
# ([Go to top](#Capstone-8:-Bringing-It-All-Together))
#
# Use this section to extract the key phrases and topics from the videos.

# %%
pip install rake-nltk
# Out:
# 7545.08s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rake-nltk) (3.9.1)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.67.1)
# Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from rake_nltk import Rake

# Load the normalized transcriptions
df = pd.read_csv("normalized_transcriptions.csv")

# Initialize RAKE
rake = Rake()

# Extract key phrases for each transcription
df["key_phrases"] = df["transcription"].apply(
    lambda text: rake.extract_keywords_from_text(text) or rake.get_ranked_phrases()
)

# Save the updated CSV file
df.to_csv("transcriptions_with_key_phrases.csv", index=False)

# %% [markdown]
# ## 5. Creating the dashboard
# ([Go to top](#Capstone-8:-Bringing-It-All-Together))
#
# Use this section to create the dashboard for your solution.

# %%
pip install dash pandas
# Out:
# Collecting dash
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.5.3)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash) (6.0.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash) (6.11.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash) (75.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (1.26.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotly>=5.0.0->dash) (21.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->dash) (2025.1.31)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging->plotly>=5.0.0->dash) (3.2.1)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.2 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, retrying, Flask, dash
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 retrying-1.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-dash
# Out:
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dash in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (2.18.2)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (2.32.3)
# Requirement already satisfied: flask in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (3.0.3)
# Requirement already satisfied: retrying in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (8.32.0)
# Requirement already satisfied: ipykernel in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (6.29.5)
# Collecting ansi2html (from jupyter-dash)
#   Downloading ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (6.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (6.11.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (4.12.2)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from dash->jupyter-dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask->jupyter-dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask->jupyter-dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask->jupyter-dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask->jupyter-dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (0.1.7)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (21.3)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: exceptiongroup in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (2.19.1)
# Requirement already satisfied: stack_data in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from ipython->jupyter-dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->jupyter-dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->jupyter-dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->jupyter-dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->jupyter-dash) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from retrying->jupyter-dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask->jupyter-dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.26.0)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata->dash->jupyter-dash) (3.21.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging->ipykernel->jupyter-dash) (3.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stack_data->ipython->jupyter-dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stack_data->ipython->jupyter-dash) (3.0.0)
# Requirement already satisfied: pure_eval in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stack_data->ipython->jupyter-dash) (0.2.3)
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Installing collected packages: ansi2html, jupyter-dash
# Successfully installed ansi2html-1.9.2 jupyter-dash-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output
import os

def load_data():
    try:
        return pd.read_csv('transcriptions_with_key_phrases.csv')
    except Exception as e:
        print(f"Error loading data: {e}")
        # Return empty DataFrame with expected columns if file not found
        return pd.DataFrame(columns=['video', 'transcription', 'key_phrases'])

# search function
def search_videos(df, query):
    if not query:
        return df
    
    query = query.lower()
    mask = (
        df['video'].str.lower().str.contains(query, na=False) | 
        df['key_phrases'].str.lower().str.contains(query, na=False)
    )
    return df[mask]

# display a video item
def display_video_item(video, on_view_details):
    # Create a button for viewing details
    view_details_button = widgets.Button(
        description='View Details',
        button_style='primary',
        layout=widgets.Layout(width='100px')
    )
    
    # Set the button's click handler
    def on_view_details_clicked(b):
        on_view_details(video['video'])
    
    view_details_button.on_click(on_view_details_clicked)
    
    # Create a widget for the video item
    video_item = widgets.VBox([
        widgets.HTML(f"<h3 style='color: #2c3e50;'>{video['video']}</h3>"),
        widgets.HTML(f"<p style='color: #34495e; max-height: 80px; overflow: hidden;'>{video['key_phrases'][:200]}...</p>"),
        view_details_button
    ], layout=widgets.Layout(
        border='1px solid #ddd',
        border_radius='8px',
        padding='15px',
        margin='10px 0',
        background_color='#f9f9f9'
    ))
    
    return video_item

#display video details
def display_video_details(video):
    # Path to the video folder
    video_folder = './videos'  # Replace with the path to your video folder
    video_file = os.path.join(video_folder, video['video'])
    video_url = "https://arya-geetha-nlp.s3.us-east-1.amazonaws.com/"+ video['video']
    
    # Check if the video file exists
    if not os.path.exists(video_file):
        video_html = "<p style='color: red;'>Video file not found.</p>"
    else:
        # Embed the video player
        video_html = f"""
        <div style="border: 1px solid #ddd; border-radius: 8px; padding: 20px; background-color: #fff;">
            <h2 style="color: #2c3e50; margin-bottom: 15px;">{video['video']}</h2>
            
            <div style="background-color: #ecf0f1; height: 240px; display: flex; align-items: center; 
                        justify-content: center; margin-bottom: 20px; border-radius: 8px;">
                <video width="100%" height="240" controls>
<source src="{video_url}" type="video/mp4">
                </video>
            </div>
            
            <div style="display: flex; justify-content: space-between; color: #7f8c8d; 
                        font-size: 14px; margin-bottom: 20px;">
                <div>Video ID: {video_url}</div>
            </div>
            
            <h3 style="color: #2c3e50; margin-bottom: 10px;">Transcript</h3>
            <div style="background-color: #f8f9fa; padding: 15px; border-radius: 8px; 
                        max-height: 200px; overflow-y: auto; font-size: 14px; line-height: 1.5;">
                {video['key_phrases']}
            </div>
            
            <div style="margin-top: 20px;">
               <!-- <button class="back-btn" 
                        style="background-color: #95a5a6; color: white; border: none; 
                               padding: 8px 15px; border-radius: 4px; cursor: pointer;">
                    Back to Results
                </button> -->
                <button style="background-color: #3498db; color: white; border: none; 
                               padding: 8px 15px; border-radius: 4px; cursor: pointer; margin-left: 10px;">
                    Download Transcript
                </button>
            </div>
        </div>
        """
    
    return widgets.HTML(video_html)

# dashboard
def create_dashboard():
    # Load data
    df = load_data()
    
    # Create search widget
    search_input = widgets.Text(
        value='',
        placeholder='Search videos by content or title...',
        description='Search:',
        layout=widgets.Layout(width='70%')
    )
    
    search_button = widgets.Button(
        description='Search',
        button_style='primary',
        layout=widgets.Layout(width='100px')
    )
    
    results_output = widgets.Output()
    details_output = widgets.Output()
    
    # Function to show results
    def show_results(df):
        results_output.clear_output()
        with results_output:
            if df.empty:
                display(widgets.HTML("<p style='color: #7f8c8d;'>No videos found matching your search.</p>"))
            else:
                display(widgets.HTML(f"<h2>Search Results ({len(df)} videos)</h2>"))
                for _, video in df.iterrows():
                    display(display_video_item(video, show_video_details))
    
    # Function to show video details
    def show_video_details(video_id):
        results_output.layout.display = 'none'
        details_output.layout.display = ''
        details_output.clear_output()
        with details_output:
            video = df[df['video'] == video_id].iloc[0]
            display(display_video_details(video))
            
            # Add a back button
            back_button = widgets.Button(
                description='Back to Results',
                button_style='warning',
                layout=widgets.Layout(width='150px')
            )
            
            def on_back_button_clicked(b):
                results_output.layout.display = ''
                details_output.layout.display = 'none'
                show_results(df)
            
            back_button.on_click(on_back_button_clicked)
            display(back_button)
    
    # Search button click
    def on_search_button_clicked(b):
        query = search_input.value
        results = search_videos(df, query)
        show_results(results)
    
    search_button.on_click(on_search_button_clicked)
    
    # Search on enter key
    def on_enter(sender):
        if sender.value:
            on_search_button_clicked(None)
    
    search_input.on_submit(on_enter)
    
    # Layout
    header = widgets.HTML(
        value="<h1 style='color: #2c3e50;'>AWS Video Search Dashboard</h1>"
    )
    
    search_box = widgets.HBox([search_input, search_button])
    
    # Initialize with all results
    show_results(df)
    
    # Initially hide details panel
    details_output.layout.display = 'none'
    
    # Display dashboard
    display(header)
    display(search_box)
    display(results_output)
    display(details_output)

# Run the dashboard
create_dashboard()
# Out:
# HTML(value="<h1 style='color: #2c3e50;'>AWS Video Search Dashboard</h1>")
# HBox(children=(Text(value='', description='Search:', layout=Layout(width='70%'), placeholder='Search videos by…
# Output()
# Output(layout=Layout(display='none'))

# %%
# !pip install flask
# Out:
# ['Requirement already satisfied: flask in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.1.0)',
#  'Requirement already satisfied: Werkzeug>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (3.1.3)',
#  'Requirement already satisfied: Jinja2>=3.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (3.1.5)',
#  'Requirement already satisfied: itsdangerous>=2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (2.2.0)',
#  'Requirement already satisfied: click>=8.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (8.1.8)',
#  'Requirement already satisfied: blinker>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (1.9.0)',
#  'Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask) (3.0.2)']

# %%
# !python appF.py
# Out:
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Serving Flask app 'appF'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8080
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Debugger is active!
#  * Debugger PIN: 102-876-032
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [22/Mar/2025 23:48:14] "GET / HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
#
# Looking for videos in module 1
# Total rows in CSV: 46
# Sample video names: ['Mod04_Intro.mp4', 'Mod03_Intro.mp4', 'Mod06_Intro.mp4', 'Mod02_Intro.mp4', 'Mod03_Sect07_part1.mp4']
#
# Looking for videos with prefix: Mod01
# Found 1 videos for module 1
# Sample video names found: ['Mod01_Course Overview.mp4']
# Returning 1 videos
# 127.0.0.1 - - [22/Mar/2025 23:48:17] "GET /api/videos/1 HTTP/1.1" 200 -
#  * Detected change in '/home/ec2-user/SageMaker/app.py', reloading
#  * Detected change in '/home/ec2-user/SageMaker/.ipynb_checkpoints/app-checkpoint.py', reloading
#  * Restarting with watchdog (inotify)
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Debugger is active!
#  * Debugger PIN: 102-876-032
# ^C

# %%
# !python dashboard.py
# Out:
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Serving Flask app 'dashboard'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://172.16.75.118:8080
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Debugger is active!
#  * Debugger PIN: 102-876-032
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [22/Mar/2025 23:47:48] "GET / HTTP/1.1" 200 -
# ^C

# %%
# !python appF.py
# Out:
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Serving Flask app 'appF'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8080
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
# Flask app is ready to run!
# 1. Make sure your CSV file is named 'transcriptions_with_key_phrases.csv' in the same directory
# 2. Run the app with: python appF.py
# 3. Access the dashboard at: http://127.0.0.1:8080/
#  * Debugger is active!
#  * Debugger PIN: 295-155-872
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [24/Mar/2025 17:40:34] "GET / HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [24/Mar/2025 17:40:34] "GET / HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
#
# Looking for videos in module 1
# Total rows in CSV: 46
# Sample video names: ['Mod04_Intro.mp4', 'Mod03_Intro.mp4', 'Mod06_Intro.mp4', 'Mod02_Intro.mp4', 'Mod03_Sect07_part1.mp4']
#
# Looking for videos with prefix: Mod01
# Found 1 videos for module 1
# Sample video names found: ['Mod01_Course Overview.mp4']
# Returning 1 videos
# 127.0.0.1 - - [24/Mar/2025 17:40:53] "GET /api/videos/1 HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
#
# Looking for videos in module 2
# Total rows in CSV: 46
# Sample video names: ['Mod04_Intro.mp4', 'Mod03_Intro.mp4', 'Mod06_Intro.mp4', 'Mod02_Intro.mp4', 'Mod03_Sect07_part1.mp4']
#
# Looking for videos with prefix: Mod02
# Found 7 videos for module 2
# Sample video names found: ['Mod02_Intro.mp4', 'Mod02_Sect03.mp4', 'Mod02_Sect05.mp4', 'Mod02_WrapUp.mp4', 'Mod02_Sect04.mp4']
# Returning 7 videos
# 127.0.0.1 - - [24/Mar/2025 17:41:02] "GET /api/videos/2 HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
#
# Looking for videos in module 1
# Total rows in CSV: 46
# Sample video names: ['Mod04_Intro.mp4', 'Mod03_Intro.mp4', 'Mod06_Intro.mp4', 'Mod02_Intro.mp4', 'Mod03_Sect07_part1.mp4']
#
# Looking for videos with prefix: Mod01
# Found 1 videos for module 1
# Sample video names found: ['Mod01_Course Overview.mp4']
# Returning 1 videos
# 127.0.0.1 - - [24/Mar/2025 17:41:08] "GET /api/videos/1 HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
#
# Looking for videos in module 2
# Total rows in CSV: 46
# Sample video names: ['Mod04_Intro.mp4', 'Mod03_Intro.mp4', 'Mod06_Intro.mp4', 'Mod02_Intro.mp4', 'Mod03_Sect07_part1.mp4']
#
# Looking for videos with prefix: Mod02
# Found 7 videos for module 2
# Sample video names found: ['Mod02_Intro.mp4', 'Mod02_Sect03.mp4', 'Mod02_Sect05.mp4', 'Mod02_WrapUp.mp4', 'Mod02_Sect04.mp4']
# Returning 7 videos
# 127.0.0.1 - - [24/Mar/2025 17:41:10] "GET /api/videos/2 HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [24/Mar/2025 17:41:17] "GET /api/search?q=machinne HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [24/Mar/2025 17:41:22] "GET /api/search?q=machine HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
# 127.0.0.1 - - [24/Mar/2025 17:41:24] "GET /api/search?q=machine HTTP/1.1" 200 -
# Loading data from transcriptions_with_key_phrases.csv...
# Successfully loaded 46 rows
# Columns: ['video', 'transcription', 'key_phrases']
#
# Sample video names:
# 0           Mod04_Intro.mp4
# 1           Mod03_Intro.mp4
# 2           Mod06_Intro.mp4
# 3           Mod02_Intro.mp4
# 4    Mod03_Sect07_part1.mp4
# Name: video, dtype: object
#
# Unique video prefixes:
# ['Mod04' 'Mod03' 'Mod06' 'Mod02' 'Mod07' 'Mod05' 'Mod01']
#
# Looking for videos in module 4
# Total rows in CSV: 46
# Sample video names: ['Mod04_Intro.mp4', 'Mod03_Intro.mp4', 'Mod06_Intro.mp4', 'Mod02_Intro.mp4', 'Mod03_Sect07_part1.mp4']
#
# Looking for videos with prefix: Mod04
# Found 6 videos for module 4
# Sample video names found: ['Mod04_Intro.mp4', 'Mod04_Sect01.mp4', 'Mod04_Sect02_part3.mp4', 'Mod04_WrapUp.mp4', 'Mod04_Sect02_part2.mp4']
# Returning 6 videos
# 127.0.0.1 - - [24/Mar/2025 17:41:46] "GET /api/videos/4 HTTP/1.1" 200 -
